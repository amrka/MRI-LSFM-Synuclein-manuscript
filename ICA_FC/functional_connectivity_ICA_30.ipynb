# %% [markdown]
# # I validated nilearn conn matrix manually against individual timeseries labels and it checks out

# %%
import numpy as np
import os
import matplotlib.pyplot as plt
import networkx as nx
from IPython.display import display, Image, SVG
import pandas as pd
from matplotlib import rcParams
rcParams["path.simplify"] = True
rcParams["path.simplify_threshold"] = 0.5
# Set the font to Arial
rcParams['font.family'] = 'Arial'
rcParams['svg.fonttype'] = 'none'
from matplotlib.pyplot import colorbar
import matplotlib.patheffects as pe
from nilearn import plotting, connectome
from sympy import symbols, Eq, solve
from mne_connectivity.viz import plot_connectivity_circle
from mne.viz import circular_layout
import sys
from matplotlib.colors import ListedColormap
import matplotlib.patches as mpatches
sys.path.append("/Users/aeed/Dropbox/SCRIPTS/functional_connectivity")
from FC_functions import combine_list, average_csv_list, plot_pcolor_map, plot_unsym_conn_mat, reduce_conn_matrix, plot_connectivity_circle2,create_flattened_csv, plot_conn_rows, average_R_then_L_csv_list, plot_unsym_conn_mat, quadrant_means_to_2x2, quadrant_RMSE_to_2x2, reshape_R_then_L, average_R_then_L_csv_list, reshape_R_then_L_stats, plot_conn_matrix

# %% [markdown]
# # ================================PALM========================

# %%
# atlas labels
labels_ICA_list = ['Amygdala',
                   'Prefrontal cortex',
                   'Anterior somatomotor/somatosensory',
                   'Posterior somatomotor/somatosensory',
                   'DMN'
                   ]

# %%
no_rois = len(labels_ICA_list)

# %%
labels_ICA_list
# Out:
# ['Amygdala',
#  'Prefrontal cortex',
#  'Anterior somatomotor/somatosensory',
#  'Posterior somatomotor/somatosensory',
#  'DMN']

# %%
# %%bash
# # session 1 vs session 2
# orig_dir="/Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/FC_ICA/FC_ICA_30_stats"
# rm -rf "${orig_dir}/partial_correlation"
# for conn in ${orig_dir}/*correlation*; do
#     #if [ -d "${conn}" ]; then
#         conn=$(basename $conn)
#
#         touch ${orig_dir}/${conn}/PBS_ses-01_${conn}.txt
#         ls --color=never ${orig_dir}/${conn}/ses-01/PBS_*_ses-01_${conn}_mat_flat.csv > ${orig_dir}/${conn}/PBS_ses-01_${conn}.txt
#
#         touch ${orig_dir}/${conn}/PFF_ses-01_${conn}.txt
#         ls --color=never ${orig_dir}/${conn}/ses-01/PFF_*_ses-01_${conn}_mat_flat.csv > ${orig_dir}/${conn}/PFF_ses-01_${conn}.txt
#
#     #fi
#
# done

# %%
# %%bash
# # session 1 vs session 2
# orig_dir="/Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/FC_ICA/FC_ICA_30_stats"
# rm -rf "${orig_dir}/partial_correlation"
# for conn in ${orig_dir}/*correlation*; do
#     #if [ -d "${conn}" ]; then
#         conn=$(basename $conn)
#
#         touch ${orig_dir}/${conn}/PBS_ses-01_${conn}.txt
#         ls --color=never ${orig_dir}/${conn}/ses-01/PBS_*_ses-01_${conn}_mat_flat.csv > ${orig_dir}/${conn}/PBS_${conn}.txt
#
#         touch ${orig_dir}/${conn}/PFF_ses-01_${conn}.txt
#         ls --color=never ${orig_dir}/${conn}/ses-01/PFF_*_ses-01_${conn}_mat_flat.csv > ${orig_dir}/${conn}/PFF_${conn}.txt
#
#     #fi
#
# done

# %%
# read the txt file, and get the number of lines and that will be the number of subjects
orig_dir="/Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/FC_ICA/FC_ICA_30_stats"
conn = "correlation"
PBS_file = f"{orig_dir}/{conn}/PBS_ses-01_{conn}.txt"
PFF_file = f"{orig_dir}/{conn}/PFF_ses-01_{conn}.txt"
with open(PBS_file, 'r') as f:
    lines = f.readlines()
    num_subjects = len(lines)
PBS_n_subjects = num_subjects

with open(PFF_file, 'r') as f:
    lines = f.readlines()
    num_subjects = len(lines)

PFF_n_subjects = num_subjects

# %% [markdown]
# # ++++++++++++++++++++++++++<font color="red"> Correlation</font>+++++++++++++++++++++++++++++++++++

# %%
PBS_s1_correlation = average_csv_list("/Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/FC_ICA/FC_ICA_30_stats/correlation/PBS_ses-01_correlation.txt")[0]

PFF_s1_correlation = average_csv_list("/Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/FC_ICA/FC_ICA_30_stats/correlation/PFF_ses-01_correlation.txt")[0]


# percentage change
# PBS_s2_vs_s1_correlation = (PBS_s2_correlation - PBS_s1_correlation) / ((PBS_s1_correlation)) * 100
# PFF_s2_vs_s1_correlation = (PFF_s2_correlation - PFF_s1_correlation) / ((PFF_s1_correlation)) * 100
#
#
#
# PBS_PFF_s1_correlation = (PBS_s1_correlation - PFF_s1_correlation) / ((PFF_s1_correlation)) * 100
# PBS_PFF_s2_correlation = (PBS_s2_correlation - PFF_s2_correlation) / ((PFF_s2_correlation)) * 100

# %%
from nilearn import plotting

# create a six subplots figure
fig, axs = plt.subplots(1, 2, figsize=(25, 8))
# fig.suptitle('Apoe3 \n Concussed Baseline')
# plot the first subplot using plotting 
fig.suptitle(f' Full Correlation ({PBS_n_subjects} PBS, {PFF_n_subjects} PFF)', fontsize=20)
vmin_val = -0.5
vmax_val = 0.5


vmin_val_ch = -50
vmax_val_ch = +50

title_font = 10
title_y_pos = 0.9
title_x_pos = 0.4

cbar_x_pos = 6
cbar_y_pos = 2

# [0,0]
plot_conn_matrix(
    axs[0],
    PBS_s1_correlation,


    labels=labels_ICA_list,
    vmax=vmax_val,
    vmin=vmin_val,
    # reorder=True,
    # grid=False,
    # tri='lower',
    cmap='coolwarm',
    cbar_shrink=1,
    # auto_fit=True,

)
axs[0].set_title('PBS Baseline', fontsize=title_font, y=title_y_pos, x=title_x_pos)
axs[0].text(cbar_x_pos, cbar_y_pos,  'z-score', fontsize=12, rotation=90, verticalalignment='center', horizontalalignment='center')



# [0,2]
plot_conn_matrix(
    axs[1],
    PFF_s1_correlation,


    labels=labels_ICA_list,
    vmax=vmax_val,
    vmin=vmin_val,
    # reorder=True,
    # grid=False,
    # tri='lower',
    cmap='coolwarm',
    cbar_shrink=1,
    # auto_fit=True,

)
axs[1].set_title('PFF baseline', fontsize=title_font, y=title_y_pos, x=title_x_pos)
axs[1].text(cbar_x_pos, cbar_y_pos,  'z-score', fontsize=12, rotation=90, verticalalignment='center', horizontalalignment='center')




for ax in axs.flat:
    ax.grid(False)
    # remove the horizontal and vertical lines around the matrix
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.spines['bottom'].set_visible(False)


# plt.subplots_adjust(left=0, right=1, bottom=0, top=0.9, wspace=0, hspace=0)


plt.savefig("/Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/FC_ICA/FC_ICA_30_stats/correlation/correlation.svg")
plt.show()

# %%
create_flattened_csv("/Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/FC_ICA/FC_ICA_30_stats/correlation/PBS_correlation.txt", "/Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/FC_ICA/FC_ICA_30_stats/correlation/PBS_correlation.csv")

create_flattened_csv("/Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/FC_ICA/FC_ICA_30_stats/correlation/PFF_correlation.txt", "/Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/FC_ICA/FC_ICA_30_stats/correlation/PFF_correlation.csv")

# %%
PBS_correlation_csv = np.genfromtxt("/Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/FC_ICA/FC_ICA_30_stats/correlation/PBS_correlation.csv", delimiter=",")
PFF_correlation_csv = np.genfromtxt("/Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/FC_ICA/FC_ICA_30_stats/correlation/PFF_correlation.csv", delimiter=",")

# %%
orig_dir = "/Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/FC_ICA/FC_ICA_30_stats"
# PBS
PBS_s1 = PBS_correlation_csv[:]
np.savetxt(f"{orig_dir}/correlation/PBS_s1.csv", PBS_s1, delimiter=",")


# PFF
PFF_s1 = PFF_correlation_csv[:]
np.savetxt(f"{orig_dir}/correlation/PFF_s1.csv", PFF_s1, delimiter=",")

# %%
PBS_vs_PFF = np.concatenate((PBS_s1, PFF_s1), axis=0)
np.savetxt(f"{orig_dir}/correlation/PBS_vs_PFF.csv", PBS_vs_PFF, delimiter=",")

# %%
# %%bash
# # palm concussion
# orig_dir="/Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/FC_ICA/FC_ICA_30_stats"
#
# design_PBS_vs_PFF="/Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/UNPAIRED_stats_design/5_vs_5.mat"
# contrast_PBS_vs_PFF="/Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/UNPAIRED_stats_design/5_vs_5.con"
# #EB_PBS_vs_PFF="/Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/UNPAIRED_stats_design/EB_9.mat"
#
#
# sub_list="${orig_dir}/correlation/PBS_vs_PFF.csv"
# output_dir="${orig_dir}/correlation"
# palm -i $sub_list -d ${design_PBS_vs_PFF} -t ${contrast_PBS_vs_PFF}  -o ${output_dir}/PBS_vs_PFF -n 10000  -fdr -ise -ee -corrcon
# Out:
# =======================================================================
#              ___         ___                         ___
#             /  /\       /  /\                       /__/\
#            /  /::\     /  /::\                     |  |::\
#           /  /:/\:\   /  /:/\:\    ___     ___     |  |:|:\
#          /  /:/~/:/  /  /:/~/::\  /__/\   /  /\  __|__|:|\:\
#         /__/:/ /:/  /__/:/ /:/\:\ \  \:\ /  /:/ /__/::::| \:\
#         \  \:\/:/   \  \:\/:/__\/  \  \:\  /:/  \  \:\~~\__\/
#          \  \::/     \  \::/        \  \:\/:/    \  \:\
#           \  \:\      \  \:\         \  \::/      \  \:\
#            \  \:\      \  \:\         \__\/        \  \:\
#             \__\/       \__\/                       \__\/
#
# =======================================================================
#                  Permutation Analysis of Linear Models
# =======================================================================
# Running PALM alpha119 using MATLAB 9.11.0.1809720 (R2021b) Update 1 with the following options:
# -i /Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/FC_ICA/FC_ICA_30_stats/correlation/PBS_vs_PFF.csv
# -d /Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/UNPAIRED_stats_design/5_vs_5.mat
# -t /Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/UNPAIRED_stats_design/5_vs_5.con
# -o /Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/FC_ICA/FC_ICA_30_stats/correlation/PBS_vs_PFF
# -n 10000
# -fdr
# -ise
# -ee
# -corrcon
# Found FSL in /usr/local/fsl
# Found FreeSurfer in /Applications/freesurfer/7.2.0
# Found SPM in /Users/aeed/Downloads/spm12
# Found HCP Workbench executable in /Users/aeed/Downloads/workbench/bin_macosx64/wb_command
# Reading input 1/1: /Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/FC_ICA/FC_ICA_30_stats/correlation/PBS_vs_PFF.csv
# Reading design matrix and contrasts.
# Elapsed time parsing inputs: ~ 15.1174 seconds.
# Number of possible permutations is 252.
# Number of possible sign-flips is 1024 = 2^10.
# Generating 10000 shufflings (permutations and sign-flips).
# Building null distribution.
# 0.005%	 [Shuffling 1/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 	 Saving file: /Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/FC_ICA/FC_ICA_30_stats/correlation/PBS_vs_PFF_dat_tstat_c1
# 0.01%	 [Shuffling 1/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 	 Saving file: /Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/FC_ICA/FC_ICA_30_stats/correlation/PBS_vs_PFF_dat_tstat_c2
# 0.015%	 [Shuffling 2/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.02%	 [Shuffling 2/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.025%	 [Shuffling 3/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.03%	 [Shuffling 3/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.035%	 [Shuffling 4/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.04%	 [Shuffling 4/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.045%	 [Shuffling 5/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.05%	 [Shuffling 5/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.055%	 [Shuffling 6/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.06%	 [Shuffling 6/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.065%	 [Shuffling 7/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.07%	 [Shuffling 7/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.075%	 [Shuffling 8/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.08%	 [Shuffling 8/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.085%	 [Shuffling 9/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.09%	 [Shuffling 9/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.095%	 [Shuffling 10/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.1%	 [Shuffling 10/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.105%	 [Shuffling 11/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.11%	 [Shuffling 11/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.115%	 [Shuffling 12/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.12%	 [Shuffling 12/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.125%	 [Shuffling 13/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.13%	 [Shuffling 13/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.135%	 [Shuffling 14/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.14%	 [Shuffling 14/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.145%	 [Shuffling 15/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.15%	 [Shuffling 15/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.155%	 [Shuffling 16/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.16%	 [Shuffling 16/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.165%	 [Shuffling 17/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.17%	 [Shuffling 17/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.175%	 [Shuffling 18/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.18%	 [Shuffling 18/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.185%	 [Shuffling 19/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.19%	 [Shuffling 19/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.195%	 [Shuffling 20/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.2%	 [Shuffling 20/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.205%	 [Shuffling 21/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.21%	 [Shuffling 21/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.215%	 [Shuffling 22/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.22%	 [Shuffling 22/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.225%	 [Shuffling 23/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.23%	 [Shuffling 23/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.235%	 [Shuffling 24/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.24%	 [Shuffling 24/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.245%	 [Shuffling 25/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.25%	 [Shuffling 25/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.255%	 [Shuffling 26/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.26%	 [Shuffling 26/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.265%	 [Shuffling 27/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.27%	 [Shuffling 27/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.275%	 [Shuffling 28/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.28%	 [Shuffling 28/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.285%	 [Shuffling 29/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.29%	 [Shuffling 29/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.295%	 [Shuffling 30/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.3%	 [Shuffling 30/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.305%	 [Shuffling 31/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.31%	 [Shuffling 31/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.315%	 [Shuffling 32/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.32%	 [Shuffling 32/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.325%	 [Shuffling 33/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.33%	 [Shuffling 33/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.335%	 [Shuffling 34/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.34%	 [Shuffling 34/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.345%	 [Shuffling 35/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.35%	 [Shuffling 35/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.355%	 [Shuffling 36/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.36%	 [Shuffling 36/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.365%	 [Shuffling 37/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.37%	 [Shuffling 37/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.375%	 [Shuffling 38/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.38%	 [Shuffling 38/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.385%	 [Shuffling 39/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.39%	 [Shuffling 39/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.395%	 [Shuffling 40/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.4%	 [Shuffling 40/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.405%	 [Shuffling 41/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.41%	 [Shuffling 41/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.415%	 [Shuffling 42/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.42%	 [Shuffling 42/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.425%	 [Shuffling 43/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.43%	 [Shuffling 43/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.435%	 [Shuffling 44/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.44%	 [Shuffling 44/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.445%	 [Shuffling 45/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.45%	 [Shuffling 45/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.455%	 [Shuffling 46/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.46%	 [Shuffling 46/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.465%	 [Shuffling 47/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.47%	 [Shuffling 47/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.475%	 [Shuffling 48/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.48%	 [Shuffling 48/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.485%	 [Shuffling 49/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.49%	 [Shuffling 49/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.495%	 [Shuffling 50/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.5%	 [Shuffling 50/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.505%	 [Shuffling 51/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.51%	 [Shuffling 51/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.515%	 [Shuffling 52/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.52%	 [Shuffling 52/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.525%	 [Shuffling 53/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.53%	 [Shuffling 53/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.535%	 [Shuffling 54/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.54%	 [Shuffling 54/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.545%	 [Shuffling 55/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.55%	 [Shuffling 55/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.555%	 [Shuffling 56/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.56%	 [Shuffling 56/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.565%	 [Shuffling 57/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.57%	 [Shuffling 57/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.575%	 [Shuffling 58/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.58%	 [Shuffling 58/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.585%	 [Shuffling 59/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.59%	 [Shuffling 59/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.595%	 [Shuffling 60/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.6%	 [Shuffling 60/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.605%	 [Shuffling 61/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.61%	 [Shuffling 61/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.615%	 [Shuffling 62/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.62%	 [Shuffling 62/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.625%	 [Shuffling 63/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.63%	 [Shuffling 63/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.635%	 [Shuffling 64/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.64%	 [Shuffling 64/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.645%	 [Shuffling 65/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.65%	 [Shuffling 65/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.655%	 [Shuffling 66/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.66%	 [Shuffling 66/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.665%	 [Shuffling 67/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.67%	 [Shuffling 67/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.675%	 [Shuffling 68/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.68%	 [Shuffling 68/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.685%	 [Shuffling 69/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.69%	 [Shuffling 69/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.695%	 [Shuffling 70/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.7%	 [Shuffling 70/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.705%	 [Shuffling 71/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.71%	 [Shuffling 71/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.715%	 [Shuffling 72/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.72%	 [Shuffling 72/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.725%	 [Shuffling 73/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.73%	 [Shuffling 73/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.735%	 [Shuffling 74/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.74%	 [Shuffling 74/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.745%	 [Shuffling 75/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.75%	 [Shuffling 75/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.755%	 [Shuffling 76/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.76%	 [Shuffling 76/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.765%	 [Shuffling 77/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.77%	 [Shuffling 77/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.775%	 [Shuffling 78/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.78%	 [Shuffling 78/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.785%	 [Shuffling 79/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.79%	 [Shuffling 79/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.795%	 [Shuffling 80/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.8%	 [Shuffling 80/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.805%	 [Shuffling 81/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.81%	 [Shuffling 81/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.815%	 [Shuffling 82/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.82%	 [Shuffling 82/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.825%	 [Shuffling 83/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.83%	 [Shuffling 83/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.835%	 [Shuffling 84/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.84%	 [Shuffling 84/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.845%	 [Shuffling 85/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.85%	 [Shuffling 85/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.855%	 [Shuffling 86/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.86%	 [Shuffling 86/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.865%	 [Shuffling 87/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.87%	 [Shuffling 87/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.875%	 [Shuffling 88/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.88%	 [Shuffling 88/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.885%	 [Shuffling 89/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.89%	 [Shuffling 89/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.895%	 [Shuffling 90/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.9%	 [Shuffling 90/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.905%	 [Shuffling 91/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.91%	 [Shuffling 91/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.915%	 [Shuffling 92/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.92%	 [Shuffling 92/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.925%	 [Shuffling 93/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.93%	 [Shuffling 93/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.935%	 [Shuffling 94/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.94%	 [Shuffling 94/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.945%	 [Shuffling 95/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.95%	 [Shuffling 95/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.955%	 [Shuffling 96/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.96%	 [Shuffling 96/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.965%	 [Shuffling 97/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.97%	 [Shuffling 97/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.975%	 [Shuffling 98/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.98%	 [Shuffling 98/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.985%	 [Shuffling 99/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 0.99%	 [Shuffling 99/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 0.995%	 [Shuffling 100/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1%	 [Shuffling 100/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1%	 [Shuffling 101/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.01%	 [Shuffling 101/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.01%	 [Shuffling 102/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.02%	 [Shuffling 102/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.02%	 [Shuffling 103/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.03%	 [Shuffling 103/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.03%	 [Shuffling 104/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.04%	 [Shuffling 104/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.04%	 [Shuffling 105/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.05%	 [Shuffling 105/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.05%	 [Shuffling 106/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.06%	 [Shuffling 106/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.06%	 [Shuffling 107/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.07%	 [Shuffling 107/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.07%	 [Shuffling 108/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.08%	 [Shuffling 108/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.08%	 [Shuffling 109/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.09%	 [Shuffling 109/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.09%	 [Shuffling 110/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.1%	 [Shuffling 110/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.1%	 [Shuffling 111/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.11%	 [Shuffling 111/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.11%	 [Shuffling 112/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.12%	 [Shuffling 112/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.12%	 [Shuffling 113/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.13%	 [Shuffling 113/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.14%	 [Shuffling 114/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.14%	 [Shuffling 114/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.15%	 [Shuffling 115/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.15%	 [Shuffling 115/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.16%	 [Shuffling 116/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.16%	 [Shuffling 116/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.17%	 [Shuffling 117/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.17%	 [Shuffling 117/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.18%	 [Shuffling 118/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.18%	 [Shuffling 118/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.19%	 [Shuffling 119/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.19%	 [Shuffling 119/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.2%	 [Shuffling 120/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.2%	 [Shuffling 120/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.21%	 [Shuffling 121/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.21%	 [Shuffling 121/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.22%	 [Shuffling 122/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.22%	 [Shuffling 122/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.23%	 [Shuffling 123/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.23%	 [Shuffling 123/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.24%	 [Shuffling 124/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.24%	 [Shuffling 124/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.25%	 [Shuffling 125/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.25%	 [Shuffling 125/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.25%	 [Shuffling 126/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.26%	 [Shuffling 126/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.26%	 [Shuffling 127/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.27%	 [Shuffling 127/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.27%	 [Shuffling 128/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.28%	 [Shuffling 128/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.28%	 [Shuffling 129/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.29%	 [Shuffling 129/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.29%	 [Shuffling 130/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.3%	 [Shuffling 130/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.3%	 [Shuffling 131/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.31%	 [Shuffling 131/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.31%	 [Shuffling 132/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.32%	 [Shuffling 132/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.32%	 [Shuffling 133/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.33%	 [Shuffling 133/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.33%	 [Shuffling 134/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.34%	 [Shuffling 134/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.34%	 [Shuffling 135/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.35%	 [Shuffling 135/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.35%	 [Shuffling 136/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.36%	 [Shuffling 136/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.36%	 [Shuffling 137/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.37%	 [Shuffling 137/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.38%	 [Shuffling 138/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.38%	 [Shuffling 138/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.39%	 [Shuffling 139/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.39%	 [Shuffling 139/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.4%	 [Shuffling 140/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.4%	 [Shuffling 140/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.41%	 [Shuffling 141/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.41%	 [Shuffling 141/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.42%	 [Shuffling 142/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.42%	 [Shuffling 142/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.43%	 [Shuffling 143/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.43%	 [Shuffling 143/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.44%	 [Shuffling 144/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.44%	 [Shuffling 144/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.45%	 [Shuffling 145/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.45%	 [Shuffling 145/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.46%	 [Shuffling 146/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.46%	 [Shuffling 146/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.47%	 [Shuffling 147/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.47%	 [Shuffling 147/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.48%	 [Shuffling 148/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.48%	 [Shuffling 148/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.49%	 [Shuffling 149/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.49%	 [Shuffling 149/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.5%	 [Shuffling 150/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.5%	 [Shuffling 150/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.5%	 [Shuffling 151/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.51%	 [Shuffling 151/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.51%	 [Shuffling 152/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.52%	 [Shuffling 152/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.52%	 [Shuffling 153/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.53%	 [Shuffling 153/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.53%	 [Shuffling 154/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.54%	 [Shuffling 154/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.54%	 [Shuffling 155/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.55%	 [Shuffling 155/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.55%	 [Shuffling 156/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.56%	 [Shuffling 156/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.56%	 [Shuffling 157/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.57%	 [Shuffling 157/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.57%	 [Shuffling 158/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.58%	 [Shuffling 158/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.58%	 [Shuffling 159/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.59%	 [Shuffling 159/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.59%	 [Shuffling 160/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.6%	 [Shuffling 160/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.6%	 [Shuffling 161/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.61%	 [Shuffling 161/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.61%	 [Shuffling 162/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.62%	 [Shuffling 162/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.62%	 [Shuffling 163/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.63%	 [Shuffling 163/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.64%	 [Shuffling 164/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.64%	 [Shuffling 164/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.65%	 [Shuffling 165/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.65%	 [Shuffling 165/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.66%	 [Shuffling 166/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.66%	 [Shuffling 166/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.67%	 [Shuffling 167/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.67%	 [Shuffling 167/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.68%	 [Shuffling 168/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.68%	 [Shuffling 168/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.69%	 [Shuffling 169/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.69%	 [Shuffling 169/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.7%	 [Shuffling 170/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.7%	 [Shuffling 170/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.71%	 [Shuffling 171/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.71%	 [Shuffling 171/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.72%	 [Shuffling 172/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.72%	 [Shuffling 172/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.73%	 [Shuffling 173/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.73%	 [Shuffling 173/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.74%	 [Shuffling 174/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.74%	 [Shuffling 174/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.75%	 [Shuffling 175/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.75%	 [Shuffling 175/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.75%	 [Shuffling 176/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.76%	 [Shuffling 176/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.76%	 [Shuffling 177/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.77%	 [Shuffling 177/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.77%	 [Shuffling 178/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.78%	 [Shuffling 178/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.78%	 [Shuffling 179/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.79%	 [Shuffling 179/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.79%	 [Shuffling 180/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.8%	 [Shuffling 180/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.8%	 [Shuffling 181/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.81%	 [Shuffling 181/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.81%	 [Shuffling 182/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.82%	 [Shuffling 182/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.82%	 [Shuffling 183/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.83%	 [Shuffling 183/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.83%	 [Shuffling 184/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.84%	 [Shuffling 184/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.84%	 [Shuffling 185/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.85%	 [Shuffling 185/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.85%	 [Shuffling 186/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.86%	 [Shuffling 186/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.86%	 [Shuffling 187/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.87%	 [Shuffling 187/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.88%	 [Shuffling 188/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.88%	 [Shuffling 188/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.89%	 [Shuffling 189/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.89%	 [Shuffling 189/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.9%	 [Shuffling 190/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.9%	 [Shuffling 190/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.91%	 [Shuffling 191/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.91%	 [Shuffling 191/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.92%	 [Shuffling 192/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.92%	 [Shuffling 192/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.93%	 [Shuffling 193/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.93%	 [Shuffling 193/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.94%	 [Shuffling 194/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.94%	 [Shuffling 194/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.95%	 [Shuffling 195/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.95%	 [Shuffling 195/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.96%	 [Shuffling 196/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.96%	 [Shuffling 196/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.97%	 [Shuffling 197/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.97%	 [Shuffling 197/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.98%	 [Shuffling 198/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.98%	 [Shuffling 198/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 1.99%	 [Shuffling 199/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 1.99%	 [Shuffling 199/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2%	 [Shuffling 200/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2%	 [Shuffling 200/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2%	 [Shuffling 201/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.01%	 [Shuffling 201/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.02%	 [Shuffling 202/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.02%	 [Shuffling 202/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.02%	 [Shuffling 203/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.03%	 [Shuffling 203/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.04%	 [Shuffling 204/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.04%	 [Shuffling 204/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.04%	 [Shuffling 205/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.05%	 [Shuffling 205/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.06%	 [Shuffling 206/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.06%	 [Shuffling 206/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.06%	 [Shuffling 207/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.07%	 [Shuffling 207/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.08%	 [Shuffling 208/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.08%	 [Shuffling 208/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.08%	 [Shuffling 209/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.09%	 [Shuffling 209/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.1%	 [Shuffling 210/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.1%	 [Shuffling 210/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.1%	 [Shuffling 211/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.11%	 [Shuffling 211/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.12%	 [Shuffling 212/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.12%	 [Shuffling 212/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.12%	 [Shuffling 213/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.13%	 [Shuffling 213/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.13%	 [Shuffling 214/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.14%	 [Shuffling 214/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.15%	 [Shuffling 215/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.15%	 [Shuffling 215/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.15%	 [Shuffling 216/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.16%	 [Shuffling 216/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.17%	 [Shuffling 217/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.17%	 [Shuffling 217/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.17%	 [Shuffling 218/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.18%	 [Shuffling 218/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.19%	 [Shuffling 219/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.19%	 [Shuffling 219/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.19%	 [Shuffling 220/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.2%	 [Shuffling 220/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.21%	 [Shuffling 221/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.21%	 [Shuffling 221/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.21%	 [Shuffling 222/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.22%	 [Shuffling 222/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.23%	 [Shuffling 223/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.23%	 [Shuffling 223/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.23%	 [Shuffling 224/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.24%	 [Shuffling 224/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.25%	 [Shuffling 225/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.25%	 [Shuffling 225/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.25%	 [Shuffling 226/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.26%	 [Shuffling 226/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.27%	 [Shuffling 227/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.27%	 [Shuffling 227/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.27%	 [Shuffling 228/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.28%	 [Shuffling 228/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.29%	 [Shuffling 229/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.29%	 [Shuffling 229/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.29%	 [Shuffling 230/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.3%	 [Shuffling 230/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.31%	 [Shuffling 231/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.31%	 [Shuffling 231/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.31%	 [Shuffling 232/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.32%	 [Shuffling 232/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.33%	 [Shuffling 233/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.33%	 [Shuffling 233/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.33%	 [Shuffling 234/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.34%	 [Shuffling 234/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.35%	 [Shuffling 235/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.35%	 [Shuffling 235/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.35%	 [Shuffling 236/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.36%	 [Shuffling 236/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.37%	 [Shuffling 237/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.37%	 [Shuffling 237/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.38%	 [Shuffling 238/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.38%	 [Shuffling 238/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.38%	 [Shuffling 239/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.39%	 [Shuffling 239/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.4%	 [Shuffling 240/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.4%	 [Shuffling 240/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.4%	 [Shuffling 241/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.41%	 [Shuffling 241/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.42%	 [Shuffling 242/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.42%	 [Shuffling 242/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.42%	 [Shuffling 243/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.43%	 [Shuffling 243/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.44%	 [Shuffling 244/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.44%	 [Shuffling 244/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.44%	 [Shuffling 245/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.45%	 [Shuffling 245/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.46%	 [Shuffling 246/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.46%	 [Shuffling 246/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.46%	 [Shuffling 247/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.47%	 [Shuffling 247/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.48%	 [Shuffling 248/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.48%	 [Shuffling 248/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.48%	 [Shuffling 249/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.49%	 [Shuffling 249/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.5%	 [Shuffling 250/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.5%	 [Shuffling 250/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.5%	 [Shuffling 251/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.51%	 [Shuffling 251/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.52%	 [Shuffling 252/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.52%	 [Shuffling 252/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.52%	 [Shuffling 253/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.53%	 [Shuffling 253/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.54%	 [Shuffling 254/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.54%	 [Shuffling 254/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.54%	 [Shuffling 255/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.55%	 [Shuffling 255/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.56%	 [Shuffling 256/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.56%	 [Shuffling 256/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.56%	 [Shuffling 257/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.57%	 [Shuffling 257/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.58%	 [Shuffling 258/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.58%	 [Shuffling 258/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.58%	 [Shuffling 259/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.59%	 [Shuffling 259/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.6%	 [Shuffling 260/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.6%	 [Shuffling 260/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.6%	 [Shuffling 261/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.61%	 [Shuffling 261/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.62%	 [Shuffling 262/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.62%	 [Shuffling 262/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.62%	 [Shuffling 263/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.63%	 [Shuffling 263/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.63%	 [Shuffling 264/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.64%	 [Shuffling 264/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.65%	 [Shuffling 265/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.65%	 [Shuffling 265/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.65%	 [Shuffling 266/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.66%	 [Shuffling 266/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.67%	 [Shuffling 267/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.67%	 [Shuffling 267/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.67%	 [Shuffling 268/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.68%	 [Shuffling 268/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.69%	 [Shuffling 269/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.69%	 [Shuffling 269/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.69%	 [Shuffling 270/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.7%	 [Shuffling 270/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.71%	 [Shuffling 271/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.71%	 [Shuffling 271/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.71%	 [Shuffling 272/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.72%	 [Shuffling 272/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.73%	 [Shuffling 273/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.73%	 [Shuffling 273/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.73%	 [Shuffling 274/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.74%	 [Shuffling 274/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.75%	 [Shuffling 275/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.75%	 [Shuffling 275/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.75%	 [Shuffling 276/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.76%	 [Shuffling 276/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.77%	 [Shuffling 277/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.77%	 [Shuffling 277/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.77%	 [Shuffling 278/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.78%	 [Shuffling 278/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.79%	 [Shuffling 279/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.79%	 [Shuffling 279/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.79%	 [Shuffling 280/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.8%	 [Shuffling 280/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.81%	 [Shuffling 281/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.81%	 [Shuffling 281/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.81%	 [Shuffling 282/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.82%	 [Shuffling 282/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.83%	 [Shuffling 283/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.83%	 [Shuffling 283/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.83%	 [Shuffling 284/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.84%	 [Shuffling 284/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.85%	 [Shuffling 285/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.85%	 [Shuffling 285/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.85%	 [Shuffling 286/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.86%	 [Shuffling 286/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.87%	 [Shuffling 287/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.87%	 [Shuffling 287/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.88%	 [Shuffling 288/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.88%	 [Shuffling 288/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.88%	 [Shuffling 289/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.89%	 [Shuffling 289/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.9%	 [Shuffling 290/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.9%	 [Shuffling 290/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.9%	 [Shuffling 291/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.91%	 [Shuffling 291/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.92%	 [Shuffling 292/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.92%	 [Shuffling 292/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.92%	 [Shuffling 293/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.93%	 [Shuffling 293/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.94%	 [Shuffling 294/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.94%	 [Shuffling 294/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.94%	 [Shuffling 295/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.95%	 [Shuffling 295/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.96%	 [Shuffling 296/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.96%	 [Shuffling 296/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.96%	 [Shuffling 297/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.97%	 [Shuffling 297/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.98%	 [Shuffling 298/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.98%	 [Shuffling 298/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 2.98%	 [Shuffling 299/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 2.99%	 [Shuffling 299/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 3%	 [Shuffling 300/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 3%	 [Shuffling 300/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 3%	 [Shuffling 301/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 3.01%	 [Shuffling 301/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 3.02%	 [Shuffling 302/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 3.02%	 [Shuffling 302/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 3.02%	 [Shuffling 303/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 3.03%	 [Shuffling 303/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 3.04%	 [Shuffling 304/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 3.04%	 [Shuffling 304/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 3.04%	 [Shuffling 305/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 3.05%	 [Shuffling 305/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 3.06%	 [Shuffling 306/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 3.06%	 [Shuffling 306/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 3.06%	 [Shuffling 307/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 3.07%	 [Shuffling 307/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 3.08%	 [Shuffling 308/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 3.08%	 [Shuffling 308/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 3.08%	 [Shuffling 309/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 3.09%	 [Shuffling 309/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 3.1%	 [Shuffling 310/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 3.1%	 [Shuffling 310/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 3.1%	 [Shuffling 311/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 3.11%	 [Shuffling 311/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 3.12%	 [Shuffling 312/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 3.12%	 [Shuffling 312/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 3.12%	 [Shuffling 313/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 3.13%	 [Shuffling 313/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 3.13%	 [Shuffling 314/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 3.14%	 [Shuffling 314/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 3.15%	 [Shuffling 315/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 3.15%	 [Shuffling 315/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 3.15%	 [Shuffling 316/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 3.16%	 [Shuffling 316/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 3.17%	 [Shuffling 317/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 3.17%	 [Shuffling 317/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 3.17%	 [Shuffling 318/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 3.18%	 [Shuffling 318/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 3.19%	 [Shuffling 319/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 3.19%	 [Shuffling 319/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 3.19%	 [Shuffling 320/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 3.2%	 [Shuffling 320/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 3.21%	 [Shuffling 321/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 3.21%	 [Shuffling 321/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 3.21%	 [Shuffling 322/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 3.22%	 [Shuffling 322/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 3.23%	 [Shuffling 323/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 3.23%	 [Shuffling 323/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 3.23%	 [Shuffling 324/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 3.24%	 [Shuffling 324/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 3.25%	 [Shuffling 325/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 3.25%	 [Shuffling 325/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 3.25%	 [Shuffling 326/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 3.26%	 [Shuffling 326/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 3.27%	 [Shuffling 327/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 3.27%	 [Shuffling 327/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 3.27%	 [Shuffling 328/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 3.28%	 [Shuffling 328/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 3.29%	 [Shuffling 329/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 3.29%	 [Shuffling 329/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 3.29%	 [Shuffling 330/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 3.3%	 [Shuffling 330/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 3.31%	 [Shuffling 331/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 3.31%	 [Shuffling 331/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 3.31%	 [Shuffling 332/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 3.32%	 [Shuffling 332/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# ...
# 99%	 [Shuffling 9900/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99%	 [Shuffling 9900/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99%	 [Shuffling 9901/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99%	 [Shuffling 9901/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99%	 [Shuffling 9902/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99%	 [Shuffling 9902/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99%	 [Shuffling 9903/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99%	 [Shuffling 9903/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99%	 [Shuffling 9904/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99%	 [Shuffling 9904/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99%	 [Shuffling 9905/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99%	 [Shuffling 9905/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.1%	 [Shuffling 9906/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.1%	 [Shuffling 9906/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.1%	 [Shuffling 9907/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.1%	 [Shuffling 9907/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.1%	 [Shuffling 9908/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.1%	 [Shuffling 9908/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.1%	 [Shuffling 9909/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.1%	 [Shuffling 9909/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.1%	 [Shuffling 9910/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.1%	 [Shuffling 9910/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.1%	 [Shuffling 9911/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.1%	 [Shuffling 9911/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.1%	 [Shuffling 9912/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.1%	 [Shuffling 9912/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.1%	 [Shuffling 9913/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.1%	 [Shuffling 9913/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.1%	 [Shuffling 9914/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.1%	 [Shuffling 9914/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.1%	 [Shuffling 9915/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.2%	 [Shuffling 9915/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.2%	 [Shuffling 9916/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.2%	 [Shuffling 9916/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.2%	 [Shuffling 9917/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.2%	 [Shuffling 9917/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.2%	 [Shuffling 9918/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.2%	 [Shuffling 9918/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.2%	 [Shuffling 9919/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.2%	 [Shuffling 9919/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.2%	 [Shuffling 9920/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.2%	 [Shuffling 9920/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.2%	 [Shuffling 9921/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.2%	 [Shuffling 9921/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.2%	 [Shuffling 9922/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.2%	 [Shuffling 9922/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.2%	 [Shuffling 9923/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.2%	 [Shuffling 9923/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.2%	 [Shuffling 9924/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.2%	 [Shuffling 9924/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.2%	 [Shuffling 9925/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.2%	 [Shuffling 9925/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.3%	 [Shuffling 9926/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.3%	 [Shuffling 9926/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.3%	 [Shuffling 9927/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.3%	 [Shuffling 9927/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.3%	 [Shuffling 9928/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.3%	 [Shuffling 9928/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.3%	 [Shuffling 9929/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.3%	 [Shuffling 9929/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.3%	 [Shuffling 9930/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.3%	 [Shuffling 9930/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.3%	 [Shuffling 9931/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.3%	 [Shuffling 9931/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.3%	 [Shuffling 9932/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.3%	 [Shuffling 9932/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.3%	 [Shuffling 9933/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.3%	 [Shuffling 9933/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.3%	 [Shuffling 9934/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.3%	 [Shuffling 9934/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.3%	 [Shuffling 9935/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.3%	 [Shuffling 9935/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.4%	 [Shuffling 9936/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.4%	 [Shuffling 9936/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.4%	 [Shuffling 9937/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.4%	 [Shuffling 9937/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.4%	 [Shuffling 9938/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.4%	 [Shuffling 9938/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.4%	 [Shuffling 9939/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.4%	 [Shuffling 9939/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.4%	 [Shuffling 9940/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.4%	 [Shuffling 9940/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.4%	 [Shuffling 9941/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.4%	 [Shuffling 9941/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.4%	 [Shuffling 9942/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.4%	 [Shuffling 9942/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.4%	 [Shuffling 9943/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.4%	 [Shuffling 9943/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.4%	 [Shuffling 9944/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.4%	 [Shuffling 9944/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.4%	 [Shuffling 9945/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.5%	 [Shuffling 9945/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.5%	 [Shuffling 9946/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.5%	 [Shuffling 9946/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.5%	 [Shuffling 9947/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.5%	 [Shuffling 9947/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.5%	 [Shuffling 9948/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.5%	 [Shuffling 9948/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.5%	 [Shuffling 9949/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.5%	 [Shuffling 9949/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.5%	 [Shuffling 9950/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.5%	 [Shuffling 9950/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.5%	 [Shuffling 9951/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.5%	 [Shuffling 9951/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.5%	 [Shuffling 9952/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.5%	 [Shuffling 9952/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.5%	 [Shuffling 9953/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.5%	 [Shuffling 9953/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.5%	 [Shuffling 9954/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.5%	 [Shuffling 9954/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.5%	 [Shuffling 9955/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.5%	 [Shuffling 9955/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.6%	 [Shuffling 9956/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.6%	 [Shuffling 9956/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.6%	 [Shuffling 9957/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.6%	 [Shuffling 9957/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.6%	 [Shuffling 9958/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.6%	 [Shuffling 9958/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.6%	 [Shuffling 9959/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.6%	 [Shuffling 9959/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.6%	 [Shuffling 9960/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.6%	 [Shuffling 9960/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.6%	 [Shuffling 9961/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.6%	 [Shuffling 9961/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.6%	 [Shuffling 9962/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.6%	 [Shuffling 9962/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.6%	 [Shuffling 9963/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.6%	 [Shuffling 9963/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.6%	 [Shuffling 9964/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.6%	 [Shuffling 9964/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.6%	 [Shuffling 9965/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.7%	 [Shuffling 9965/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.7%	 [Shuffling 9966/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.7%	 [Shuffling 9966/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.7%	 [Shuffling 9967/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.7%	 [Shuffling 9967/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.7%	 [Shuffling 9968/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.7%	 [Shuffling 9968/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.7%	 [Shuffling 9969/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.7%	 [Shuffling 9969/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.7%	 [Shuffling 9970/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.7%	 [Shuffling 9970/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.7%	 [Shuffling 9971/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.7%	 [Shuffling 9971/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.7%	 [Shuffling 9972/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.7%	 [Shuffling 9972/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.7%	 [Shuffling 9973/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.7%	 [Shuffling 9973/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.7%	 [Shuffling 9974/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.7%	 [Shuffling 9974/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.7%	 [Shuffling 9975/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.8%	 [Shuffling 9975/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.8%	 [Shuffling 9976/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.8%	 [Shuffling 9976/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.8%	 [Shuffling 9977/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.8%	 [Shuffling 9977/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.8%	 [Shuffling 9978/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.8%	 [Shuffling 9978/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.8%	 [Shuffling 9979/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.8%	 [Shuffling 9979/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.8%	 [Shuffling 9980/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.8%	 [Shuffling 9980/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.8%	 [Shuffling 9981/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.8%	 [Shuffling 9981/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.8%	 [Shuffling 9982/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.8%	 [Shuffling 9982/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.8%	 [Shuffling 9983/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.8%	 [Shuffling 9983/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.8%	 [Shuffling 9984/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.8%	 [Shuffling 9984/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.8%	 [Shuffling 9985/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.8%	 [Shuffling 9985/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.9%	 [Shuffling 9986/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.9%	 [Shuffling 9986/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.9%	 [Shuffling 9987/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.9%	 [Shuffling 9987/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.9%	 [Shuffling 9988/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.9%	 [Shuffling 9988/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.9%	 [Shuffling 9989/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.9%	 [Shuffling 9989/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.9%	 [Shuffling 9990/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.9%	 [Shuffling 9990/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.9%	 [Shuffling 9991/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.9%	 [Shuffling 9991/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.9%	 [Shuffling 9992/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.9%	 [Shuffling 9992/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.9%	 [Shuffling 9993/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.9%	 [Shuffling 9993/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.9%	 [Shuffling 9994/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 99.9%	 [Shuffling 9994/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 99.9%	 [Shuffling 9995/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 100%	 [Shuffling 9995/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 100%	 [Shuffling 9996/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 100%	 [Shuffling 9996/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 100%	 [Shuffling 9997/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 100%	 [Shuffling 9997/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 100%	 [Shuffling 9998/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 100%	 [Shuffling 9998/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 100%	 [Shuffling 9999/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 100%	 [Shuffling 9999/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# 100%	 [Shuffling 10000/10000, Design 1/1, Contrast 1/2, Modality 1/1]
# 100%	 [Shuffling 10000/10000, Design 1/1, Contrast 2/2, Modality 1/1]
# Elapsed time with permutations: ~ 9.57857 seconds.
# Computing p-values.
# Saving p-values (uncorrected, and corrected within modality and within contrast).
# 	 Saving file: /Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/FC_ICA/FC_ICA_30_stats/correlation/PBS_vs_PFF_dat_tstat_uncp_c1
# 	 Saving file: /Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/FC_ICA/FC_ICA_30_stats/correlation/PBS_vs_PFF_dat_tstat_fwep_c1
# 	 Saving file: /Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/FC_ICA/FC_ICA_30_stats/correlation/PBS_vs_PFF_dat_tstat_fdrp_c1
# 	 Saving file: /Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/FC_ICA/FC_ICA_30_stats/correlation/PBS_vs_PFF_dat_tstat_uncp_c2
# 	 Saving file: /Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/FC_ICA/FC_ICA_30_stats/correlation/PBS_vs_PFF_dat_tstat_fwep_c2
# 	 Saving file: /Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/FC_ICA/FC_ICA_30_stats/correlation/PBS_vs_PFF_dat_tstat_fdrp_c2
# Saving p-values (corrected across contrasts).
# 	 Saving file: /Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/FC_ICA/FC_ICA_30_stats/correlation/PBS_vs_PFF_dat_tstat_cfdrp_c1
# 	 Saving file: /Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/FC_ICA/FC_ICA_30_stats/correlation/PBS_vs_PFF_dat_tstat_cfdrp_c2
# 	 Saving file: /Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/FC_ICA/FC_ICA_30_stats/correlation/PBS_vs_PFF_dat_tstat_cfwep_c1
# 	 Saving file: /Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/FC_ICA/FC_ICA_30_stats/correlation/PBS_vs_PFF_dat_tstat_cfwep_c2
# Elapsed time generating and saving results: ~ 0.229783 seconds.
# Overall elapsed time: ~ 24.9257 seconds.
# PALM finished at 08-Jun-2026 20:57:04.
# Error using exit
# Unrecognized function or variable 'Settings'.
#
# Error using exit
# Unrecognized function or variable 'Settings'.

# %%
from nilearn import plotting
fig, axs = plt.subplots(1, 2, figsize=(20, 10))
fig.suptitle(f'PBS vs PFF \n Full Correlation Stats  ({PBS_n_subjects} PBS, {PFF_n_subjects} PFF)', fontsize=20)
vmin_val = 0
vmax_val = 0.05
title_font = 12
title_y_pos = 0.9
title_x_pos = 0.65

cbar_x_pos = 6
cbar_y_pos = 2

stat = "UNC"
cbar_legend = f"{stat} p-value"
stat_suffix = f"{stat.lower()}p"

# [0,0]
stats_PBS_VS_PFF_c2 = np.genfromtxt(f"/Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/FC_ICA/FC_ICA_30_stats/correlation/PBS_vs_PFF_dat_tstat_{stat_suffix}_c2.csv", delimiter=",")
stats_PBS_VS_PFF_c2 = connectome.vec_to_sym_matrix(stats_PBS_VS_PFF_c2, diagonal=np.zeros(no_rois))

plot_conn_matrix(
    axs[0],
    stats_PBS_VS_PFF_c2,
    # labels=labels_ICA,
    vmax=vmax_val,
    vmin=vmin_val,
    # reorder=True,
    cmap='hot_r',

)
axs[0].set_title('PFF > PBS', fontsize=title_font, y=title_y_pos, x=title_x_pos)
axs[0].text(cbar_x_pos, cbar_y_pos,  cbar_legend, fontsize=12, rotation=90, verticalalignment='center', horizontalalignment='center')

# # [1,0]
stats_PBS_VS_PFF_c1 = np.genfromtxt(f"/Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/FC_ICA/FC_ICA_30_stats/correlation/PBS_VS_PFF_dat_tstat_{stat_suffix}_c1.csv", delimiter=",")
stats_PBS_VS_PFF_c1 = connectome.vec_to_sym_matrix(stats_PBS_VS_PFF_c1, diagonal=np.zeros(no_rois))

plot_conn_matrix(
    axs[1],
    stats_PBS_VS_PFF_c1,
    # labels=labels_ICA,
    vmax=vmax_val,
    vmin=vmin_val,
    # reorder=True,
    cmap='hot_r',

)
axs[1].set_title('PFF < PBS', fontsize=title_font, y=title_y_pos, x=title_x_pos)
axs[1].text(cbar_x_pos, cbar_y_pos,  cbar_legend, fontsize=12, rotation=90, verticalalignment='center', horizontalalignment='center')


for ax in axs.flat:
    ax.grid(False)
    # remove the horizontal and vertical lines around the matrix
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
#     
#     ax.hlines(y=22.58, xmin=0, xmax=2, colors="khaki", linewidth=7, label="Olfactory", antialiased=True)
#     ax.hlines(y=22.58, xmin=2, xmax=4, colors="navy", linewidth=7, label="Isocortex", antialiased=True)
#     ax.hlines(y=22.58, xmin=4, xmax=6, colors="green", linewidth=7, label="Hipp formation", antialiased=True)
#     ax.hlines(y=22.58, xmin=6, xmax=8, colors="purple", linewidth=7,label="Amygdala", antialiased=True)
#     ax.hlines(y=22.58, xmin=8, xmax=10, colors="orange", linewidth=7, label="Striatum", antialiased=True)
#     ax.hlines(y=22.58, xmin=10, xmax=12, colors="brown", linewidth=7, label="Pallidum", antialiased=True)
#     ax.hlines(y=22.58, xmin=12, xmax=14, colors="pink", linewidth=7, label="Thalamus", antialiased=True)
#     ax.hlines(y=22.58, xmin=14, xmax=16, colors="gray", linewidth=7, label="Hypothalamus", antialiased=True)
#     ax.hlines(y=22.58, xmin=16, xmax=18, colors="cyan", linewidth=7, label="Midbrain", antialiased=True)
#     ax.hlines(y=22.58, xmin=18, xmax=20, colors="magenta", linewidth=7, label="Hindbrain", antialiased=True)
#     ax.hlines(y=22.58, xmin=20, xmax=22, colors="lime", linewidth=7, label="Cerebellum", antialiased=True)
# # 
#     ax.vlines(x=-0.58, ymin=0, ymax=2, colors="khaki", linewidth=7, antialiased=True)
#     ax.vlines(x=-0.58, ymin=2, ymax=4, colors="navy", linewidth=7, antialiased=True)
#     ax.vlines(x=-0.58, ymin=4, ymax=6, colors="green", linewidth=7, antialiased=True)
#     ax.vlines(x=-0.58, ymin=6, ymax=8, colors="purple", linewidth=7, antialiased=True)
#     ax.vlines(x=-0.58, ymin=8, ymax=10, colors="orange", linewidth=7, antialiased=True)
#     ax.vlines(x=-0.58, ymin=10, ymax=12, colors="brown", linewidth=7, antialiased=True)
#     ax.vlines(x=-0.58, ymin=12, ymax=14, colors="pink", linewidth=7, antialiased=True)
#     ax.vlines(x=-0.58, ymin=14, ymax=16, colors="gray", linewidth=7, antialiased=True)
#     ax.vlines(x=-0.58, ymin=16, ymax=18, colors="cyan", linewidth=7, antialiased=True)
#     ax.vlines(x=-0.58, ymin=18, ymax=20, colors="magenta", linewidth=7, antialiased=True)
#     ax.vlines(x=-0.58, ymin=20, ymax=22, colors="lime", linewidth=7, antialiased=True)
# ax.legend(loc='center', bbox_to_anchor=(1.6, 1.1))
# ax.text(-42,-12, "PBS", fontsize=20, rotation=90)
# ax.text(-42,15, "PFF", fontsize=20, rotation=90)


# ax.text(-17,27, "corrected for sex", fontsize=20, rotation=0)
plt.savefig(f"/Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/FC_ICA/FC_ICA_30_stats/correlation/Correlation_stats_{stat_suffix}.svg")
plt.show()
