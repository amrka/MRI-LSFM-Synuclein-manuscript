# %% [markdown]
# # <font color="F54927"> ================number of events per paw=================</font>

# %%
# !python count_events.py /Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/paws_regressors2
# Out:
# ...
# EVENT COUNTS PER FILE
# ...
#   sub-hM835603942971011M8 | ses-01 | run-1 | Left Paw: 1 events
#   sub-hM835603942971011M8 | ses-01 | run-1 | Right Paw: 2 events
#   sub-hM835603942971011M8 | ses-01 | run-2 | Left Paw: 1 events
#   sub-hM835603942971011M8 | ses-01 | run-2 | Right Paw: 4 events
#   sub-hM835603942971011M8 | ses-01 | run-3 | Left Paw: 1 events
#   sub-hM835603942971011M8 | ses-01 | run-3 | Right Paw: 2 events
#   sub-hM835603942971011M8 | ses-01 | run-4 | Left Paw: 5 events
#   sub-hM835603942971011M8 | ses-01 | run-4 | Right Paw: 5 events
#   sub-hM8362224086051084M2 | ses-01 | run-1 | Left Paw: 10 events
#   sub-hM8362224086051084M2 | ses-01 | run-1 | Right Paw: 11 events
#   sub-hM8362224086051084M2 | ses-01 | run-2 | Left Paw: 11 events
#   sub-hM8362224086051084M2 | ses-01 | run-2 | Right Paw: 12 events
#   sub-hM8362224086051084M2 | ses-01 | run-3 | Left Paw: 5 events
#   sub-hM8362224086051084M2 | ses-01 | run-3 | Right Paw: 5 events
# ...

# %%
# !python count_events.py /Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/paws_regressors2 2>&1 | tee /dev/tty
# Out:
# ...
# EVENT COUNTS PER FILE
# ...
# EVENT COUNTS PER FILE
# ...
#   sub-hM835603942971011M8 | ses-01 | run-1 | Left Paw: 1 events
#   sub-hM835603942971011M8 | ses-01 | run-1 | Left Paw: 1 events
#   sub-hM835603942971011M8 | ses-01 | run-1 | Right Paw: 2 events
#   sub-hM835603942971011M8 | ses-01 | run-1 | Right Paw: 2 events
#   sub-hM835603942971011M8 | ses-01 | run-2 | Left Paw: 1 events
#   sub-hM835603942971011M8 | ses-01 | run-2 | Left Paw: 1 events
#   sub-hM835603942971011M8 | ses-01 | run-2 | Right Paw: 4 events
#   sub-hM835603942971011M8 | ses-01 | run-2 | Right Paw: 4 events
#   sub-hM835603942971011M8 | ses-01 | run-3 | Left Paw: 1 events
#   sub-hM835603942971011M8 | ses-01 | run-3 | Left Paw: 1 events
#   sub-hM835603942971011M8 | ses-01 | run-3 | Right Paw: 2 events
#   sub-hM835603942971011M8 | ses-01 | run-3 | Right Paw: 2 events
#   sub-hM835603942971011M8 | ses-01 | run-4 | Left Paw: 5 events
#   sub-hM835603942971011M8 | ses-01 | run-4 | Left Paw: 5 events
# ...
