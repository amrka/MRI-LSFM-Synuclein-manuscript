# %% [markdown]
# # <font color='red'>===================0003 subjbect wise correlations===================</font>

# %%
import os
import glob
import shutil
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rcParams
import matplotlib.patches as mpatches
rcParams["path.simplify"] = True
rcParams["path.simplify_threshold"] = 0.5
# Set the font to Arial
rcParams['font.family'] = 'Arial'
rcParams['svg.fonttype'] = 'none'
from correlation_functions import process_regional_metrics, average_multiple_dfs, get_rgb_color_vector, brainsmash_correlation, correlate_tsv_columns, get_centroids, correlate_subjectwise_tsv_columns, create_subjectwise_tsv

# %%
working_dir = "/Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/BrainSMASH_correlations"
no_surrogates = 1000

# %%
cd $working_dir
# Out:
# /Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/BrainSMASH_correlations

# %%
pff_subjects = [
    "sub-hM8362334086041083M6",
    "sub-hM836323993941035M4",
    "sub-hM8363224086001085M5",
    "sub-hM836373993921113M9",
    "sub-hM8362324086031084M5",
]

# %% [markdown]
# # <font color="#28cf33ff"> ================DBM-fieldfraction correlation================

# %%
dbm_sub_list = glob.glob(f"{working_dir}/metrics/DBM/sub-*bilateral.tsv")
print(dbm_sub_list)

fieldfraction_sub_list = glob.glob(f"{working_dir}/metrics/fieldfraction/sub-*bilateral.tsv")
print(fieldfraction_sub_list)
# Out:
# ['/Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/BrainSMASH_correlations/metrics/DBM/sub-hM8362324086031084M5_DBM_bilateral.tsv', '/Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/BrainSMASH_correlations/metrics/DBM/sub-hM836323993941035M4_DBM_bilateral.tsv', '/Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/BrainSMASH_correlations/metrics/DBM/sub-hM8362334086041083M6_DBM_bilateral.tsv', '/Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/BrainSMASH_correlations/metrics/DBM/sub-hM836373993921113M9_DBM_bilateral.tsv', '/Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/BrainSMASH_correlations/metrics/DBM/sub-hM8363224086001085M5_DBM_bilateral.tsv']
# ...

# %%
correlate_subjectwise_tsv_columns(tsv_list1=fieldfraction_sub_list,
                                  tsv_list2=dbm_sub_list,
                                  col1="aSync+fieldfrac_bilateral",
                                  col2="mean_voxel_value_bilateral",
                                  subject_names=pff_subjects,
                                  x_label="pS129 Field Fraction",
                                  y_label="W-score",
                                  output_dir=f"{working_dir}/correlations/DBM_fieldfraction",
                                  output_file_stem="DBM_fieldfraction_subjectwise_correlation")
# Out:
# Saved to /Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/BrainSMASH_correlations/correlations/DBM_fieldfraction/DBM_fieldfraction_subjectwise_correlation.svg / .pdf
# array([<Axes: title={'center': 'subject 1'}, xlabel='pS129 Field Fraction', ylabel='W-score'>,
#        <Axes: title={'center': 'subject 2'}, xlabel='pS129 Field Fraction', ylabel='W-score'>,
#        <Axes: title={'center': 'subject 3'}, xlabel='pS129 Field Fraction', ylabel='W-score'>,
#        <Axes: title={'center': 'subject 4'}, xlabel='pS129 Field Fraction', ylabel='W-score'>,
#        <Axes: title={'center': 'subject 5'}, xlabel='pS129 Field Fraction', ylabel='W-score'>],
#       dtype=object)

# %% [markdown]
# # <font color="#28cf33ff"> ================DBM-fieldfraction_stephanie correlation================

# %%
dbm_stephanie_sub_list = glob.glob(f"{working_dir}/metrics/DBM_stephanie/sub-*bilateral.tsv")
print(dbm_stephanie_sub_list)

fieldfraction_sub_list = glob.glob(f"{working_dir}/metrics/fieldfraction/sub-*bilateral.tsv")
print(fieldfraction_sub_list)
# Out:
# ['/Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/BrainSMASH_correlations/metrics/DBM_stephanie/sub-hM8363224086001085M5_DBM_stephanie_bilateral.tsv', '/Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/BrainSMASH_correlations/metrics/DBM_stephanie/sub-hM836373993921113M9_DBM_stephanie_bilateral.tsv', '/Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/BrainSMASH_correlations/metrics/DBM_stephanie/sub-hM836323993941035M4_DBM_stephanie_bilateral.tsv', '/Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/BrainSMASH_correlations/metrics/DBM_stephanie/sub-hM8362324086031084M5_DBM_stephanie_bilateral.tsv', '/Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/BrainSMASH_correlations/metrics/DBM_stephanie/sub-hM8362334086041083M6_DBM_stephanie_bilateral.tsv']
# ...

# %%
correlate_subjectwise_tsv_columns(tsv_list1=fieldfraction_sub_list,
                                  tsv_list2=dbm_stephanie_sub_list,
                                  col1="aSync+fieldfrac_bilateral",
                                  col2="mean_voxel_value_bilateral",
                                  subject_names=pff_subjects,
                                  x_label="pS129 Field Fraction",
                                  y_label="W-score",
                                  output_dir=f"{working_dir}/correlations/DBM_fieldfraction_stephanie",
                                  output_file_stem="DBM_fieldfraction_subjectwise_stephanie_correlation")
# Out:
# Saved to /Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/BrainSMASH_correlations/correlations/DBM_fieldfraction_stephanie/DBM_fieldfraction_subjectwise_stephanie_correlation.svg / .pdf
# array([<Axes: title={'center': 'subject 1'}, xlabel='pS129 Field Fraction', ylabel='W-score'>,
#        <Axes: title={'center': 'subject 2'}, xlabel='pS129 Field Fraction', ylabel='W-score'>,
#        <Axes: title={'center': 'subject 3'}, xlabel='pS129 Field Fraction', ylabel='W-score'>,
#        <Axes: title={'center': 'subject 4'}, xlabel='pS129 Field Fraction', ylabel='W-score'>,
#        <Axes: title={'center': 'subject 5'}, xlabel='pS129 Field Fraction', ylabel='W-score'>],
#       dtype=object)

# %% [markdown]
# # <font color="#28cf33ff"> ================regional_TA-fieldfraction correlation================================

# %%
regional_TA_sub_list = glob.glob(f"{working_dir}/metrics/regional_TA/sub-*bilateral.tsv")
print(regional_TA_sub_list)

fieldfraction_sub_list = glob.glob(f"{working_dir}/metrics/fieldfraction/sub-*bilateral.tsv")
print(fieldfraction_sub_list)
# Out:
# ['/Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/BrainSMASH_correlations/metrics/regional_TA/sub-hM836373993921113M9_regional_TA_bilateral.tsv', '/Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/BrainSMASH_correlations/metrics/regional_TA/sub-hM8363224086001085M5_regional_TA_bilateral.tsv', '/Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/BrainSMASH_correlations/metrics/regional_TA/sub-hM8362334086041083M6_regional_TA_bilateral.tsv', '/Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/BrainSMASH_correlations/metrics/regional_TA/sub-hM836323993941035M4_regional_TA_bilateral.tsv', '/Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/BrainSMASH_correlations/metrics/regional_TA/sub-hM8362324086031084M5_regional_TA_bilateral.tsv']
# ...

# %%
correlate_subjectwise_tsv_columns(tsv_list1=fieldfraction_sub_list,
                                  tsv_list2=regional_TA_sub_list,
                                  col1="aSync+fieldfrac_bilateral",
                                  col2="regional_TA_bilateral",
                                  subject_names=pff_subjects,
                                  x_label="pS129 Field Fraction",
                                  y_label=r"regional TA-$\Delta_1$",
                                  output_dir=f"{working_dir}/correlations/regional_TA_fieldfraction",
                                  output_file_stem="regional_TA_fieldfraction_subjectwise_correlation")
# Out:
# Saved to /Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/BrainSMASH_correlations/correlations/regional_TA_fieldfraction/regional_TA_fieldfraction_subjectwise_correlation.svg / .pdf
# array([<Axes: title={'center': 'subject 1'}, xlabel='pS129 Field Fraction', ylabel='regional TA-$\\Delta_1$'>,
#        <Axes: title={'center': 'subject 2'}, xlabel='pS129 Field Fraction', ylabel='regional TA-$\\Delta_1$'>,
#        <Axes: title={'center': 'subject 3'}, xlabel='pS129 Field Fraction', ylabel='regional TA-$\\Delta_1$'>,
#        <Axes: title={'center': 'subject 4'}, xlabel='pS129 Field Fraction', ylabel='regional TA-$\\Delta_1$'>,
#        <Axes: title={'center': 'subject 5'}, xlabel='pS129 Field Fraction', ylabel='regional TA-$\\Delta_1$'>],
#       dtype=object)

# %% [markdown]
# # <font color="#28cf33ff"> ================seed conn-fieldfraction correlation================================

# %%
seed_FC_sub_list = glob.glob(f"{working_dir}/metrics/seed_FC/sub-*bilateral.tsv")
print(seed_FC_sub_list)

fieldfraction_sub_list = glob.glob(f"{working_dir}/metrics/fieldfraction/sub-*bilateral.tsv")
print(fieldfraction_sub_list)
# Out:
# ['/Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/BrainSMASH_correlations/metrics/seed_FC/sub-hM8362324086031084M5_seed_FC_bilateral.tsv', '/Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/BrainSMASH_correlations/metrics/seed_FC/sub-hM8362334086041083M6_seed_FC_bilateral.tsv', '/Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/BrainSMASH_correlations/metrics/seed_FC/sub-hM836373993921113M9_seed_FC_bilateral.tsv', '/Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/BrainSMASH_correlations/metrics/seed_FC/sub-hM836323993941035M4_seed_FC_bilateral.tsv', '/Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/BrainSMASH_correlations/metrics/seed_FC/sub-hM8363224086001085M5_seed_FC_bilateral.tsv']
# ...

# %%
correlate_subjectwise_tsv_columns(tsv_list1=fieldfraction_sub_list,
                                  tsv_list2=seed_FC_sub_list,
                                  col1="aSync+fieldfrac_bilateral",
                                  col2="mean_voxel_value_bilateral",
                                  subject_names=pff_subjects,
                                  x_label="pS129 Field Fraction",
                                  y_label="Seed-based FC",
                                  output_dir=f"{working_dir}/correlations/seed_FC_fieldfraction",
                                  output_file_stem="seed_FC_fieldfraction_subjectwise_correlation")
# Out:
# Saved to /Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/BrainSMASH_correlations/correlations/seed_FC_fieldfraction/seed_FC_fieldfraction_subjectwise_correlation.svg / .pdf
# array([<Axes: title={'center': 'subject 1'}, xlabel='pS129 Field Fraction', ylabel='Seed-based FC'>,
#        <Axes: title={'center': 'subject 2'}, xlabel='pS129 Field Fraction', ylabel='Seed-based FC'>,
#        <Axes: title={'center': 'subject 3'}, xlabel='pS129 Field Fraction', ylabel='Seed-based FC'>,
#        <Axes: title={'center': 'subject 4'}, xlabel='pS129 Field Fraction', ylabel='Seed-based FC'>,
#        <Axes: title={'center': 'subject 5'}, xlabel='pS129 Field Fraction', ylabel='Seed-based FC'>],
#       dtype=object)

# %% [markdown]
# # <font color="#28cf33ff"> ================Struc conn-fieldfrcation correlation================================

# %%
stuc_conn_tsv_file = f"{working_dir}/metrics/struc_conn/CP_avg_conn_right_positive_str_log10.tsv"

# %%
# create a subjectwise tsv file for struc conn to match the fieldfraction tsv files
create_subjectwise_tsv(tsv_file=stuc_conn_tsv_file,
                       subject_names=pff_subjects,
                       output_dir=f"{working_dir}/metrics/struc_conn",)

# %%
struc_conn_sub_list = glob.glob(f"{working_dir}/metrics/struc_conn/sub-*_CP_avg_conn_right_positive_str_log10.tsv")
print(struc_conn_sub_list)

fieldfraction_sub_list = glob.glob(f"{working_dir}/metrics/fieldfraction/sub-*_R_stru_conn.tsv")
print(fieldfraction_sub_list)
# Out:
# ['/Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/BrainSMASH_correlations/metrics/struc_conn/sub-hM836373993921113M9_CP_avg_conn_right_positive_str_log10.tsv', '/Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/BrainSMASH_correlations/metrics/struc_conn/sub-hM836323993941035M4_CP_avg_conn_right_positive_str_log10.tsv', '/Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/BrainSMASH_correlations/metrics/struc_conn/sub-hM8362324086031084M5_CP_avg_conn_right_positive_str_log10.tsv', '/Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/BrainSMASH_correlations/metrics/struc_conn/sub-hM8363224086001085M5_CP_avg_conn_right_positive_str_log10.tsv', '/Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/BrainSMASH_correlations/metrics/struc_conn/sub-hM8362334086041083M6_CP_avg_conn_right_positive_str_log10.tsv']
# ...

# %%
correlate_subjectwise_tsv_columns(tsv_list2=fieldfraction_sub_list,
                                  tsv_list1=struc_conn_sub_list,
                                  col2="aSync+fieldfrac",
                                  col1="connection_strength_log10",
                                  subject_names=pff_subjects,
                                  y_label="pS129 Field Fraction",
                                  x_label="CP stru conn (log10)",
                                  output_dir=f"{working_dir}/correlations/struc_conn_fieldfraction",
                                  output_file_stem="struc_conn_fieldfraction_subjectwise_correlation")
# Out:
# Saved to /Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/BrainSMASH_correlations/correlations/struc_conn_fieldfraction/struc_conn_fieldfraction_subjectwise_correlation.svg / .pdf
# array([<Axes: title={'center': 'subject 1'}, xlabel='CP stru conn (log10)', ylabel='pS129 Field Fraction'>,
#        <Axes: title={'center': 'subject 2'}, xlabel='CP stru conn (log10)', ylabel='pS129 Field Fraction'>,
#        <Axes: title={'center': 'subject 3'}, xlabel='CP stru conn (log10)', ylabel='pS129 Field Fraction'>,
#        <Axes: title={'center': 'subject 4'}, xlabel='CP stru conn (log10)', ylabel='pS129 Field Fraction'>,
#        <Axes: title={'center': 'subject 5'}, xlabel='CP stru conn (log10)', ylabel='pS129 Field Fraction'>],
#       dtype=object)

# %% [markdown]
# # <font color="#28cf33ff"> ================Struc conn-DBM correlation================================

# %%
struc_conn_sub_list = glob.glob(f"{working_dir}/metrics/struc_conn/sub-*_CP_avg_conn_right_positive_str_log10.tsv")
print(struc_conn_sub_list)

DBM_sub_list = glob.glob(f"{working_dir}/metrics/DBM/sub-*_R_stru_conn.tsv")
print(DBM_sub_list)
# Out:
# ['/Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/BrainSMASH_correlations/metrics/struc_conn/sub-hM836373993921113M9_CP_avg_conn_right_positive_str_log10.tsv', '/Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/BrainSMASH_correlations/metrics/struc_conn/sub-hM836323993941035M4_CP_avg_conn_right_positive_str_log10.tsv', '/Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/BrainSMASH_correlations/metrics/struc_conn/sub-hM8362324086031084M5_CP_avg_conn_right_positive_str_log10.tsv', '/Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/BrainSMASH_correlations/metrics/struc_conn/sub-hM8363224086001085M5_CP_avg_conn_right_positive_str_log10.tsv', '/Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/BrainSMASH_correlations/metrics/struc_conn/sub-hM8362334086041083M6_CP_avg_conn_right_positive_str_log10.tsv']
# ...

# %%
correlate_subjectwise_tsv_columns(tsv_list2=DBM_sub_list,
                                  tsv_list1=struc_conn_sub_list,
                                  col2="mean_voxel_value",
                                  col1="connection_strength_log10",
                                  subject_names=pff_subjects,
                                  y_label="W-score",
                                  x_label="CP stru conn (log10)",
                                  output_dir=f"{working_dir}/correlations/DBM_struc_conn",
                                  output_file_stem="DBM_struc_conn_subjectwise_correlation",
                                  )
# Out:
# Saved to /Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/BrainSMASH_correlations/correlations/DBM_struc_conn/DBM_struc_conn_subjectwise_correlation.svg / .pdf
# array([<Axes: title={'center': 'subject 1'}, xlabel='CP stru conn (log10)', ylabel='W-score'>,
#        <Axes: title={'center': 'subject 2'}, xlabel='CP stru conn (log10)', ylabel='W-score'>,
#        <Axes: title={'center': 'subject 3'}, xlabel='CP stru conn (log10)', ylabel='W-score'>,
#        <Axes: title={'center': 'subject 4'}, xlabel='CP stru conn (log10)', ylabel='W-score'>,
#        <Axes: title={'center': 'subject 5'}, xlabel='CP stru conn (log10)', ylabel='W-score'>],
#       dtype=object)

# %% [markdown]
# # <font color="#28cf33ff"> ================Struc conn-DBM correlation================================

# %%
struc_conn_sub_list = glob.glob(f"{working_dir}/metrics/struc_conn/sub-*_CP_avg_conn_right_positive_str_log10.tsv")
print(struc_conn_sub_list)

DBM_stephanie_sub_list = glob.glob(f"{working_dir}/metrics/DBM_stephanie/sub-*_R_stru_conn.tsv")
print(DBM_stephanie_sub_list)
# Out:
# ['/Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/BrainSMASH_correlations/metrics/struc_conn/sub-hM836373993921113M9_CP_avg_conn_right_positive_str_log10.tsv', '/Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/BrainSMASH_correlations/metrics/struc_conn/sub-hM836323993941035M4_CP_avg_conn_right_positive_str_log10.tsv', '/Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/BrainSMASH_correlations/metrics/struc_conn/sub-hM8362324086031084M5_CP_avg_conn_right_positive_str_log10.tsv', '/Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/BrainSMASH_correlations/metrics/struc_conn/sub-hM8363224086001085M5_CP_avg_conn_right_positive_str_log10.tsv', '/Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/BrainSMASH_correlations/metrics/struc_conn/sub-hM8362334086041083M6_CP_avg_conn_right_positive_str_log10.tsv']
# ...

# %%
correlate_subjectwise_tsv_columns(tsv_list2=DBM_stephanie_sub_list,
                                  tsv_list1=struc_conn_sub_list,
                                  col2="mean_voxel_value",
                                  col1="connection_strength_log10",
                                  subject_names=pff_subjects,
                                  y_label="W-score",
                                  x_label="CP stru conn (log10)",
                                  output_dir=f"{working_dir}/correlations/DBM_struc_conn_stephanie",
                                  output_file_stem="DBM_struc_conn_subjectwise_stephanie_correlation",
                                  )
# Out:
# Saved to /Users/aeed/Documents/Work/M83_clearing/Manuscript_analysis/BrainSMASH_correlations/correlations/DBM_struc_conn_stephanie/DBM_struc_conn_subjectwise_stephanie_correlation.svg / .pdf
# array([<Axes: title={'center': 'subject 1'}, xlabel='CP stru conn (log10)', ylabel='W-score'>,
#        <Axes: title={'center': 'subject 2'}, xlabel='CP stru conn (log10)', ylabel='W-score'>,
#        <Axes: title={'center': 'subject 3'}, xlabel='CP stru conn (log10)', ylabel='W-score'>,
#        <Axes: title={'center': 'subject 4'}, xlabel='CP stru conn (log10)', ylabel='W-score'>,
#        <Axes: title={'center': 'subject 5'}, xlabel='CP stru conn (log10)', ylabel='W-score'>],
#       dtype=object)

# %% [markdown]
# # <font color="#28cf33ff"> ================plot all together================================

# %%
n = len(pff_subjects)
fig, axes = plt.subplots(n, n, figsize=(6*n, 6*n), sharex=False, sharey=False)


dbm_sub_list = glob.glob(f"{working_dir}/metrics/DBM/sub-*bilateral.tsv")
fieldfraction_sub_list = glob.glob(f"{working_dir}/metrics/fieldfraction/sub-*bilateral.tsv")
correlate_subjectwise_tsv_columns(tsv_list1=fieldfraction_sub_list,
                                  tsv_list2=dbm_sub_list,
                                  col1="aSync+fieldfrac_bilateral",
                                  col2="mean_voxel_value_bilateral",
                                  subject_names=pff_subjects,
                                  x_label="pS129 Field Fraction",
                                  y_label="W-score",
                                  output_dir=f"{working_dir}/correlations/DBM_fieldfraction",
                                  output_file_stem="DBM_fieldfraction_subjectwise_correlation",
                                  axes=axes[0])



regional_TA_sub_list = glob.glob(f"{working_dir}/metrics/regional_TA/sub-*bilateral.tsv")
fieldfraction_sub_list = glob.glob(f"{working_dir}/metrics/fieldfraction/sub-*bilateral.tsv")
correlate_subjectwise_tsv_columns(tsv_list1=fieldfraction_sub_list,
                                  tsv_list2=regional_TA_sub_list,
                                  col1="aSync+fieldfrac_bilateral",
                                  col2="regional_TA_bilateral",
                                  subject_names=pff_subjects,
                                  x_label="pS129 Field Fraction",
                                  y_label=r"regional TA-$\Delta_1$",
                                  output_dir=f"{working_dir}/correlations/regional_TA_fieldfraction",
                                  output_file_stem="regional_TA_fieldfraction_subjectwise_correlation",
                                  axes=axes[1])



seed_FC_sub_list = glob.glob(f"{working_dir}/metrics/seed_FC/sub-*bilateral.tsv")
fieldfraction_sub_list = glob.glob(f"{working_dir}/metrics/fieldfraction/sub-*bilateral.tsv")
correlate_subjectwise_tsv_columns(tsv_list1=fieldfraction_sub_list,
                                  tsv_list2=seed_FC_sub_list,
                                  col1="aSync+fieldfrac_bilateral",
                                  col2="mean_voxel_value_bilateral",
                                  subject_names=pff_subjects,
                                  x_label="pS129 Field Fraction",
                                  y_label="Seed-based FC",
                                  output_dir=f"{working_dir}/correlations/seed_FC_fieldfraction",
                                  output_file_stem="seed_FC_fieldfraction_subjectwise_correlation",
                                  axes=axes[2])




struc_conn_sub_list = glob.glob(f"{working_dir}/metrics/struc_conn/sub-*_CP_avg_conn_right_positive_str_log10.tsv")
fieldfraction_sub_list = glob.glob(f"{working_dir}/metrics/fieldfraction/sub-*_R_stru_conn.tsv")
correlate_subjectwise_tsv_columns(tsv_list2=fieldfraction_sub_list,
                                  tsv_list1=struc_conn_sub_list,
                                  col2="aSync+fieldfrac",
                                  col1="connection_strength_log10",
                                  subject_names=pff_subjects,
                                  y_label="pS129 Field Fraction",
                                  x_label="CP stru conn (log10)",
                                  output_dir=f"{working_dir}/correlations/struc_conn_fieldfraction",
                                  output_file_stem="struc_conn_fieldfraction_subjectwise_correlation",
                                  axes=axes[3])


struc_conn_sub_list = glob.glob(f"{working_dir}/metrics/struc_conn/sub-*_CP_avg_conn_right_positive_str_log10.tsv")
DBM_sub_list = glob.glob(f"{working_dir}/metrics/DBM/sub-*_R_stru_conn.tsv")
correlate_subjectwise_tsv_columns(tsv_list2=DBM_sub_list,
                                  tsv_list1=struc_conn_sub_list,
                                  col2="mean_voxel_value",
                                  col1="connection_strength_log10",
                                  subject_names=pff_subjects,
                                  y_label="W-score",
                                  x_label="CP stru conn (log10)",
                                  output_dir=f"{working_dir}/correlations/DBM_struc_conn",
                                  output_file_stem="DBM_struc_conn_subjectwise_correlation",
                                  axes=axes[4])



for row, letter in zip(range(axes.shape[0]), "ABCDE"):
    axes[row, 0].text(-0.35, 1.05, letter,
                      transform=axes[row, 0].transAxes,
                      fontsize=24, fontweight='bold', va='top', ha='right')
fig.savefig(f"{working_dir}/subject_wise_correlations.svg", bbox_inches="tight")
fig.savefig(f"{working_dir}/subject_wise_correlations.pdf", bbox_inches="tight")
fig.savefig(f"{working_dir}/subject_wise_correlations.png", bbox_inches="tight")
plt.show()

# %%
n = len(pff_subjects)
fig, axes = plt.subplots(n, n, figsize=(6*n, 6*n), sharex=False, sharey=False)


dbm_stephanie_sub_list = glob.glob(f"{working_dir}/metrics/DBM_stephanie/sub-*bilateral.tsv")
fieldfraction_sub_list = glob.glob(f"{working_dir}/metrics/fieldfraction/sub-*bilateral.tsv")
correlate_subjectwise_tsv_columns(tsv_list1=fieldfraction_sub_list,
                                  tsv_list2=dbm_stephanie_sub_list,
                                  col1="aSync+fieldfrac_bilateral",
                                  col2="mean_voxel_value_bilateral",
                                  subject_names=pff_subjects,
                                  x_label="pS129 Field Fraction",
                                  y_label="W-score",
                                  output_dir=f"{working_dir}/correlations/DBM_fieldfraction_stephanie",
                                  output_file_stem="DBM_fieldfraction_subjectwise_stephanie_correlation",
                                  axes=axes[0])



regional_TA_sub_list = glob.glob(f"{working_dir}/metrics/regional_TA/sub-*bilateral.tsv")
fieldfraction_sub_list = glob.glob(f"{working_dir}/metrics/fieldfraction/sub-*bilateral.tsv")
correlate_subjectwise_tsv_columns(tsv_list1=fieldfraction_sub_list,
                                  tsv_list2=regional_TA_sub_list,
                                  col1="aSync+fieldfrac_bilateral",
                                  col2="regional_TA_bilateral",
                                  subject_names=pff_subjects,
                                  x_label="pS129 Field Fraction",
                                  y_label=r"regional TA-$\Delta_1$",
                                  output_dir=f"{working_dir}/correlations/regional_TA_fieldfraction",
                                  output_file_stem="regional_TA_fieldfraction_subjectwise_correlation",
                                  axes=axes[1])



seed_FC_sub_list = glob.glob(f"{working_dir}/metrics/seed_FC/sub-*bilateral.tsv")
fieldfraction_sub_list = glob.glob(f"{working_dir}/metrics/fieldfraction/sub-*bilateral.tsv")
correlate_subjectwise_tsv_columns(tsv_list1=fieldfraction_sub_list,
                                  tsv_list2=seed_FC_sub_list,
                                  col1="aSync+fieldfrac_bilateral",
                                  col2="mean_voxel_value_bilateral",
                                  subject_names=pff_subjects,
                                  x_label="pS129 Field Fraction",
                                  y_label="Seed-based FC",
                                  output_dir=f"{working_dir}/correlations/seed_FC_fieldfraction",
                                  output_file_stem="seed_FC_fieldfraction_subjectwise_correlation",
                                  axes=axes[2])




struc_conn_sub_list = glob.glob(f"{working_dir}/metrics/struc_conn/sub-*_CP_avg_conn_right_positive_str_log10.tsv")
fieldfraction_sub_list = glob.glob(f"{working_dir}/metrics/fieldfraction/sub-*_R_stru_conn.tsv")
correlate_subjectwise_tsv_columns(tsv_list2=fieldfraction_sub_list,
                                  tsv_list1=struc_conn_sub_list,
                                  col2="aSync+fieldfrac",
                                  col1="connection_strength_log10",
                                  subject_names=pff_subjects,
                                  y_label="pS129 Field Fraction",
                                  x_label="CP stru conn (log10)",
                                  output_dir=f"{working_dir}/correlations/struc_conn_fieldfraction",
                                  output_file_stem="struc_conn_fieldfraction_subjectwise_correlation",
                                  axes=axes[3])


struc_conn_sub_list = glob.glob(f"{working_dir}/metrics/struc_conn/sub-*_CP_avg_conn_right_positive_str_log10.tsv")
DBM_stephanie_sub_list = glob.glob(f"{working_dir}/metrics/DBM_stephanie/sub-*_R_stru_conn.tsv")
correlate_subjectwise_tsv_columns(tsv_list2=DBM_stephanie_sub_list,
                                  tsv_list1=struc_conn_sub_list,
                                  col2="mean_voxel_value",
                                  col1="connection_strength_log10",
                                  subject_names=pff_subjects,
                                  y_label="W-score",
                                  x_label="CP stru conn (log10)",
                                  output_dir=f"{working_dir}/correlations/DBM_struc_conn_stephanie",
                                  output_file_stem="DBM_struc_conn_subjectwise_stephanie_correlation",
                                  axes=axes[4])



for row, letter in zip(range(axes.shape[0]), "ABCDE"):
    axes[row, 0].text(-0.35, 1.05, letter,
                      transform=axes[row, 0].transAxes,
                      fontsize=24, fontweight='bold', va='top', ha='right')
fig.savefig(f"{working_dir}/subject_wise_correlations_stephanie.svg", bbox_inches="tight")
fig.savefig(f"{working_dir}/subject_wise_correlations_stephanie.pdf", bbox_inches="tight")
fig.savefig(f"{working_dir}/subject_wise_correlations_stephanie.png", bbox_inches="tight")
plt.show()
